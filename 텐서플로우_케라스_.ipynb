# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.2.0'

# %%
dir(tf.random)
# Out:
# ['Algorithm',
#  'Generator',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys',
#  'all_candidate_sampler',
#  'categorical',
#  'create_rng_state',
#  'experimental',
#  'fixed_unigram_candidate_sampler',
#  'gamma',
#  'get_global_generator',
#  'learned_unigram_candidate_sampler',
#  'log_uniform_candidate_sampler',
#  'normal',
#  'poisson',
#  'set_global_generator',
#  'set_seed',
#  'shuffle',
#  'stateless_binomial',
#  'stateless_categorical',
#  'stateless_gamma',
#  'stateless_normal',
#  'stateless_poisson',
#  'stateless_truncated_normal',
#  'stateless_uniform',
#  'truncated_normal',
#  'uniform',
#  'uniform_candidate_sampler']

# %%
rand = tf.random.uniform([1],0,1)

# %%
rand
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.88756037], dtype=float32)>

# %%
rand.numpy()
# Out:
# array([0.88756037], dtype=float32)

# %%
rand4 = tf.random.uniform([4],0,1)

# %%
rand4.numpy()
# Out:
# array([0.13322413, 0.38835037, 0.40988982, 0.13025296], dtype=float32)

# %%
normal = tf.random.normal([4],0,1)

# %%
normal.numpy()
# Out:
# array([ 0.73026085, -1.6887745 , -0.63019794,  0.13357729], dtype=float32)

# %%
x = tf.constant([0.0, 1.0, 50.0, 100.0])

# %%
dir(tf.math)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_sys',
#  'abs',
#  'accumulate_n',
#  'acos',
#  'acosh',
#  'add',
#  'add_n',
#  'angle',
#  'argmax',
#  'argmin',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'bessel_i0',
#  'bessel_i0e',
#  'bessel_i1',
#  'bessel_i1e',
#  'betainc',
#  'bincount',
#  'ceil',
#  'confusion_matrix',
#  'conj',
#  'cos',
#  'cosh',
#  'count_nonzero',
#  'cumprod',
#  'cumsum',
#  'cumulative_logsumexp',
#  'digamma',
#  'divide',
#  'divide_no_nan',
#  'equal',
#  'erf',
#  'erfc',
#  'erfinv',
#  'exp',
#  'expm1',
#  'floor',
#  'floordiv',
#  'floormod',
#  'greater',
#  'greater_equal',
#  'igamma',
#  'igammac',
#  'imag',
#  'in_top_k',
#  'invert_permutation',
#  'is_finite',
#  'is_inf',
#  'is_nan',
#  'is_non_decreasing',
#  'is_strictly_increasing',
#  'l2_normalize',
#  'lbeta',
#  'less',
#  'less_equal',
#  'lgamma',
# ...

# %%
x.numpy()
# Out:
# array([  0.,   1.,  50., 100.], dtype=float32)

# %%
tf.math.sigmoid(x)
# Out:
# <tf.Tensor: shape=(4,), dtype=float32, numpy=array([0.5      , 0.7310586, 1.       , 1.       ], dtype=float32)>

# %%
help(tf.math.maximum)
# Out:
# Help on function maximum in module tensorflow.python.ops.gen_math_ops:
#
# maximum(x, y, name=None)
#     Returns the max of x and y (i.e. x > y ? x : y) element-wise.
#
#     Example:
#     >>> x = tf.constant([0., 0., 0., 0.])
#     >>> y = tf.constant([-2., 0., 2., 5.])
#     >>> tf.math.maximum(x, y)
#     <tf.Tensor: shape=(4,), dtype=float32, numpy=array([0., 0., 2., 5.], dtype=float32)>
#
#     Args:
#       x: A `Tensor`. Must be one of the following types: `bfloat16`, `half`, `float32`, `float64`, `int32`, `int64`.
#       y: A `Tensor`. Must have the same type as `x`.
#       name: A name for the operation (optional).
#
#     Returns:
#       A `Tensor`. Has the same type as `x`.

# %%
y = tf.math.maximum(x, 0.)

# %%
y.numpy()
# Out:
# array([  0.,   1.,  50., 100.], dtype=float32)

# %%
x_1 = tf.constant([0., 0., 0., 0.])
y_1 = tf.constant([-2., 0., 2., 5.])

# %%
z_1 = tf.math.maximum(x_1,y_1)

# %%
z_1.numpy()
# Out:
# array([0., 0., 2., 5.], dtype=float32)

# %%
x = 1
y = 1
w = tf.random.normal([1], 0,1)
b = tf.random.normal([1],0,1)

# %%
for i in range(1000) :
    output = tf.math.sigmoid(x * w + 1*b)
    error = y - output
    w = w + x * 0.1 *error
    b = b + 1 * 0.1 * error
    if i % 100 == 99 :
        print(i, error, output)
# Out:
# 99 tf.Tensor([0.05010027], shape=(1,), dtype=float32) tf.Tensor([0.94989973], shape=(1,), dtype=float32)
# 199 tf.Tensor([0.02542973], shape=(1,), dtype=float32) tf.Tensor([0.9745703], shape=(1,), dtype=float32)
# 299 tf.Tensor([0.01696318], shape=(1,), dtype=float32) tf.Tensor([0.9830368], shape=(1,), dtype=float32)
# 399 tf.Tensor([0.0127086], shape=(1,), dtype=float32) tf.Tensor([0.9872914], shape=(1,), dtype=float32)
# 499 tf.Tensor([0.01015413], shape=(1,), dtype=float32) tf.Tensor([0.9898459], shape=(1,), dtype=float32)
# 599 tf.Tensor([0.008452], shape=(1,), dtype=float32) tf.Tensor([0.991548], shape=(1,), dtype=float32)
# 699 tf.Tensor([0.00723726], shape=(1,), dtype=float32) tf.Tensor([0.99276274], shape=(1,), dtype=float32)
# 799 tf.Tensor([0.00632703], shape=(1,), dtype=float32) tf.Tensor([0.99367297], shape=(1,), dtype=float32)
# 899 tf.Tensor([0.0056197], shape=(1,), dtype=float32) tf.Tensor([0.9943803], shape=(1,), dtype=float32)
# ...

# %%
import numpy as np

# %%
x = np.array([[1,1], [1,0], [0,1], [0,0]])
y = np.array([[0], [1], [1], [0]])

# %%
x
# Out:
# array([[1, 1],
#        [1, 0],
#        [0, 1],
#        [0, 0]])

# %%
y
# Out:
# array([[0],
#        [1],
#        [1],
#        [0]])

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Dense(2, activation = 'sigmoid', input_shape=(2,)))

# %%
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01), loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 3
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x,y, epochs=2000, batch_size=1)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 0s 992us/step - loss: 0.2505
# Epoch 2/2000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 3/2000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 4/2000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 5/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2505
# Epoch 6/2000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 7/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2505
# Epoch 8/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2505
# Epoch 9/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2505
# Epoch 10/2000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 11/2000
# 4/4 [==============================] - 0s 950us/step - loss: 0.2505
# Epoch 12/2000
# ...

# %%
model.predict(x)
# Out:
# array([[0.49642903],
#        [0.5068096 ],
#        [0.4938264 ],
#        [0.504063  ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])

# %%
population_ins = np.array([0.3, -0.78, 1.26, 0.03, 1.11, 15.17, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66])

# %%
population_old = np.array([12.27, 14.44, 11.87, 18.75, 17.52,  9.29, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42])

# %%
population_ins.shape, population_old .shape
# Out:
# ((17,), (17,))

# %%
plt.plot(population_ins, population_old, 'bo')
plt.xlabel(' Population Growth Rate')
plt.ylabel(' Elderly Population Rate ')
plt.show()

# %%
population_ins[5], population_old[5]
# Out:
# (15.17, 9.29)

# %%
population_ins_1 = np.concatenate([population_ins[:5] ,population_ins[6:]])

# %%
population_old_1 = np.concatenate([population_old[:5] ,population_old[6:]])

# %%
population_ins_1 .shape, population_old_1.shape
# Out:
# ((16,), (16,))

# %%
plt.plot(population_ins_1, population_old_1, 'bo')
plt.xlabel(' Population Growth Rate')
plt.ylabel(' Elderly Population Rate ')
plt.show()

# %%
x_bar = population_ins_1 .mean()

# %%
y_bar = population_old_1 .mean()

# %%
X = np.array([0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66])

# %%
Y = np.array([12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42])

# %%
a = tf.Variable(np.random.random())
b = tf.Variable(np.random.random())

# %%
a.numpy(), b.numpy()
# Out:
# (0.48444593, 0.74263763)

# %%
def compute_loss() :
    y_pred = a * X + b
    loss = tf.reduce_mean((Y - y_pred) ** 2)
    return loss

# %%
optimizer = tf.optimizers.Adam(lr=0.07)

# %%
for i in range(1000) :
    optimizer.minimize(compute_loss, var_list=[a,b])
    if i % 100 == 99 :
        print(i, 'a', a.numpy(), 'b', b.numpy(), 'loss', compute_loss().numpy())
# Out:
# 99 a -0.4099452 b 15.668671 loss 9.209242
# 199 a -0.41700637 b 15.668666 loss 9.208534
# 299 a -0.41696984 b 15.668666 loss 9.208535
# 399 a -0.41653213 b 15.668665 loss 9.208537
# 499 a -0.41697428 b 15.668665 loss 9.208534
# 599 a -0.41696557 b 15.668665 loss 9.208535
# 699 a -0.41728282 b 15.668665 loss 9.208537
# 799 a -0.41697112 b 15.668665 loss 9.208535
# 899 a -0.4169682 b 15.668665 loss 9.208535
# 999 a -0.41531605 b 15.668669 loss 9.208574

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(6, activation='tanh', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.01), loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 6)                 12
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 7
# ...
# Total params: 19
# Trainable params: 19
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X, Y, epochs=10)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 0s 1ms/step - loss: 23.7793
# Epoch 2/10
# 1/1 [==============================] - 0s 3ms/step - loss: 21.1889
# Epoch 3/10
# 1/1 [==============================] - 0s 2ms/step - loss: 19.0501
# Epoch 4/10
# 1/1 [==============================] - 0s 2ms/step - loss: 17.2903
# Epoch 5/10
# 1/1 [==============================] - 0s 3ms/step - loss: 15.8471
# Epoch 6/10
# 1/1 [==============================] - 0s 1ms/step - loss: 14.6667
# Epoch 7/10
# 1/1 [==============================] - 0s 2ms/step - loss: 13.7038
# Epoch 8/10
# 1/1 [==============================] - 0s 2ms/step - loss: 12.9199
# Epoch 9/10
# 1/1 [==============================] - 0s 2ms/step - loss: 12.2832
# Epoch 10/10
# 1/1 [==============================] - 0s 3ms/step - loss: 11.7667

# %%
model.predict(X)
# Out:
# array([[14.345554],
#        [14.49025 ],
#        [14.014868],
#        [14.422775],
#        [14.062368],
#        [14.364553],
#        [14.473684],
#        [14.493639],
#        [14.49081 ],
#        [14.487558],
#        [14.485613],
#        [14.490458],
#        [14.477501],
#        [14.425175],
#        [14.491348],
#        [13.639524]], dtype=float32)

# %%
line_x = np.arange(X.min(), X.max(), 0.01)

# %%
line_y = model.predict(line_x)

# %%
plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel(' Population Growth Rate % ')
plt.ylabel(' Elderly Population Rate  % ')
plt.show()
